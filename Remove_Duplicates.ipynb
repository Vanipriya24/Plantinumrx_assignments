# %%
def remove_duplicates(s):
    unique = ""
    for char in s:
        if char not in unique:
            unique += char
    return unique

remove_duplicates("banana")
# Out:
# 'ban'

# %%
def remove_duplicates(s):
    unique = ""
    for char in s:
        if char not in unique:
            unique += char
    return unique

remove_duplicates("seed")
# Out:
# 'sed'
